# %% [markdown]
# ### Setup libraries

# %%
# !pip install deeppavlov
# Out:
# ...
#   Using cached deeppavlov-0.15.0-py3-none-any.whl (907 kB)
# ...
#   Using cached overrides-2.7.0-py3-none-any.whl
# ...
#   Using cached pymorphy2-0.8-py2.py3-none-any.whl (46 kB)
# ...
#   Using cached ruamel.yaml-0.15.100-py3-none-any.whl
# ...
#   Using cached sacremoses-0.0.35-py3-none-any.whl
# ...
#   Using cached pandas-0.25.3-cp38-cp38-win_amd64.whl (9.4 MB)
# ...
#   Using cached prometheus_client-0.7.1-py3-none-any.whl
# ...
#   Using cached nltk-3.4.5-py3-none-any.whl
# ...
#   Using cached scikit-learn-0.21.2.tar.gz (12.2 MB)
# ...
#   Using cached aio_pika-6.4.1-py3-none-any.whl (40 kB)
# ...
#   Using cached rusenttokenize-0.0.5-py3-none-any.whl (10 kB)
# ...
#   Using cached uvloop-0.14.0.tar.gz (2.0 MB)
#     ERROR: Command errored out with exit status 1:
# ...

# %% [markdown]
# ### Import libraries

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:72.5% !important; }</style>"))
# Out:
# <style>.container { width:72.5% !important; }</style>

# %%
from deeppavlov import build_model, configs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-fb2f25801da6> in <module>
# ----> 1 from deeppavlov import build_model, configs
#
# ModuleNotFoundError: No module named 'deeppavlov'

# %%
# # Training (if you have your own data)
# from deeppavlov import configs, train_evaluate_model_from_config

# train_evaluate_model_from_config(configs.doc_retrieval.ru_odqa_infer_wiki_rubert, download=True)
# train_evaluate_model_from_config(configs.squad.multi_squad_noans, download=True)

# %%
# Building
odqa = build_model(configs.odqa.ru_odqa_infer_wiki_rubert, download=true)
# Out:
# 2021-05-26 10:36:05.939 INFO in 'deeppavlov.models.vectorizers.hashing_tfidf_vectorizer'['hashing_tfidf_vectorizer'] at line 264: Loading tfidf matrix from /root/.deeppavlov/models/odqa/ruwiki_tfidf_matrix.npz

# %%
# Inference
result = odqa(['Столица России?'])
print(result)
