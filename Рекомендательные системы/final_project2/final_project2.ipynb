# %% [markdown]
# ## Финальный проект
#
# - Целевая метрика - precision@5. Порог для уcпешной сдачи проекта precision@5 > 0.27%
# - Будет public тестовый датасет, на котором вы сможете измерять метрику
# - Также будет private тестовый датасет для измерения финального качества
# - НЕ обязательно, но крайне желательно использовать 2-ух уровневые рекоммендательные системы в проекте
# - Вы сдаете код проекта в виде github репозитория и csv файл с рекомендациями

# %% [markdown]
# ### Подключение библиотек и скриптов

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:72.5% !important; }</style>"))
# Out:
# <style>.container { width:72.5% !important; }</style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from scipy.sparse import csr_matrix

from implicit import als
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# from statistics import mean

from src.metrics import precision_at_k, recall_at_k, money_precision_at_k
from src.utils import prefilter_items, extend_user_item_new_features, get_important_features, get_final_recomendations
from src.recommenders import MainRecommender

from tqdm import tqdm
tqdm.pandas()

# %%
plt.rcParams.update({'font.size': 14})
pd.set_option('precision', 3)
pd.set_option('max_columns', 100)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('max_colwidth', 300)

# %% [markdown]
# ### Пути к директориям и файлам / Загрузка данных

# %%
data = pd.read_csv('data/retail_train.csv')
data_test = pd.read_csv('data/retail_test1.csv')

item_features = pd.read_csv('data/product.csv')
user_features = pd.read_csv('data/hh_demographic.csv')

# %%
data
# Out:
#          user_id    basket_id  day   item_id  quantity  sales_value  store_id  \
# 0           2375  26984851472    1   1004906         1      1.39000       364
# 1           2375  26984851472    1   1033142         1      0.82000       364
# 2           2375  26984851472    1   1036325         1      0.99000       364
# 3           2375  26984851472    1   1082185         1      1.21000       364
# 4           2375  26984851472    1   8160430         1      1.50000       364
# ...          ...          ...  ...       ...       ...          ...       ...
# 2396799     1613  41655820646  663  16102849         1      2.00000      3262
# 2396800     1001  41655829421  663  13217063         1      1.69000      3131
# 2396801     1001  41655829421  663  13217800         1      1.69000      3131
# 2396802     1167  41656790510  663   6410462     22451     43.98000      3385
# 2396803     1167  41656790510  663   6430664         1      8.00000      3385
#
#          retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0           -0.60000        1631        1      0.00000            0.00000
# 1            0.00000        1631        1      0.00000            0.00000
# 2           -0.30000        1631        1      0.00000            0.00000
# 3            0.00000        1631        1      0.00000            0.00000
# 4           -0.39000        1631        1      0.00000            0.00000
# ...              ...         ...      ...          ...                ...
# 2396799     -1.15000        1231       95      0.00000            0.00000
# 2396800      0.00000        2231       95      0.00000            0.00000
# 2396801      0.00000        2231       95      0.00000            0.00000
# 2396802     -0.65000        1059       95      0.00000            0.00000
# 2396803      0.00000        1059       95      0.00000            0.00000
#
# [2396804 rows x 12 columns]

# %%
# data = data.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
# data.drop(['Unnamed: 0'], axis=1, inplace=True)

# column processing
item_features.columns = [col.lower() for col in item_features.columns]
user_features.columns = [col.lower() for col in user_features.columns]

item_features.rename(columns={'product_id': 'item_id'}, inplace=True)
user_features.rename(columns={'household_key': 'user_id'}, inplace=True)

# %%
# Количество рекомендаций
N=150 

VAL_SIZE = 5

train_1 = data[data['week_no'] < data['week_no'].max() - (VAL_SIZE)]
val = data[data['week_no'] >= data['week_no'].max() - (VAL_SIZE)]

train_2 = val.copy()

# %% [markdown]
# ### First level model

# %%
n_items_before = train_1['item_id'].nunique()
train_1 = prefilter_items(train_1, item_features=item_features, take_n_popular = 777)
n_items_after = train_1['item_id'].nunique()

print(f'Decreased # items from {n_items_before} to {n_items_after}')
# Out:
# Decreased # items from 85828 to 778

# %%
recommender = MainRecommender(train_1)
# Out:
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=15.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=778.0), HTML(value='')))

# %%
items_emb_df = recommender.items_emb_df
users_emb_df = recommender.users_emb_df

# %% [markdown]
# ### Add New Features

# %% [markdown]
# ![image](0_PSZK-yUYwQJsN5A8.png)

# %%
train = extend_user_item_new_features(train_2, train_1, recommender, item_features, user_features, items_emb_df, users_emb_df, N)
train.head()
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0      843  40955282722  622   845193         3      5.37000       364
# 1      843  40955282722  622   845193         3      5.37000       364
# 2      843  40955282722  622   865891         2      2.00000       364
# 3      843  40955282722  622   883404         2      1.76000       364
# 4      843  40955282722  622   904375         4      4.00000       364
#
#    retail_disc  trans_time  week_no  coupon_disc_x  coupon_match_disc   price  \
# 0     -1.50000          19       90        0.00000            0.00000 1.79000
# 1     -1.50000          19       90        0.00000            0.00000 1.79000
# 2      0.00000          19       90        0.00000            0.00000 1.00000
# 3     -0.82000          19       90        0.00000            0.00000 0.88000
# 4      0.00000          19       90        0.00000            0.00000 1.00000
#
#    manufacturer department     brand          commodity_desc  \
# 0     999999999    GROCERY  National            FROZEN PIZZA
# 1     999999999    GROCERY  National            FROZEN PIZZA
# 2           608    GROCERY  National  FRZN MEAT/MEAT DINNERS
# 3            69    GROCERY   Private  BAKED BREAD/BUNS/ROLLS
# 4           608    GROCERY  National  FRZN MEAT/MEAT DINNERS
#
#                sub_commodity_desc curr_size_of_product     0_x      1_x  \
# 0               SNACKS/APPETIZERS              10.5 OZ 0.00294 -0.00431
# 1               SNACKS/APPETIZERS              10.5 OZ 0.00294 -0.00431
# 2  SS ECONOMY ENTREES/DINNERS ALL              6.75 OZ 0.00000  0.00000
# 3          MAINSTREAM WHITE BREAD                20 OZ 0.00166 -0.00115
# 4  SS ECONOMY ENTREES/DINNERS ALL               7.5 OZ 0.00000  0.00000
#
#        2_x     3_x      4_x     5_x     6_x      7_x     8_x     9_x     10_x  \
# 0 -0.00031 0.00971 -0.00482 0.00368 0.00670 -0.00099 0.00245 0.01308  0.01354
# 1 -0.00031 0.00971 -0.00482 0.00368 0.00670 -0.00099 0.00245 0.01308  0.01354
# 2  0.00000 0.00000  0.00000 0.00000 0.00000  0.00000 0.00000 0.00000  0.00000
# 3 -0.00436 0.00328 -0.00379 0.01223 0.00929  0.00767 0.00483 0.00697 -0.00078
# 4  0.00000 0.00000  0.00000 0.00000 0.00000  0.00000 0.00000 0.00000  0.00000
#
#      11_x     12_x     13_x     14_x    15_x    16_x     17_x     18_x  \
# 0 0.00459  0.00415 -0.00604 -0.00159 0.00029 0.00612 -0.01109 -0.00598
# 1 0.00459  0.00415 -0.00604 -0.00159 0.00029 0.00612 -0.01109 -0.00598
# 2 0.00000  0.00000  0.00000  0.00000 0.00000 0.00000  0.00000  0.00000
# 3 0.00281 -0.00508  0.00645 -0.00383 0.00661 0.01090 -0.00454  0.00575
# 4 0.00000  0.00000  0.00000  0.00000 0.00000 0.00000  0.00000  0.00000
#
#       19_x  coupon_disc_y  sales_count_per_dep  \
# 0  0.01546        0.00000               112255
# 1  0.01546        0.00000               112255
# 2  0.00000        0.00000               112255
# 3 -0.00133        0.00000               112255
# 4  0.00000        0.00000               112255
#
#    qnt_of_sales_per_item_per_dep_per_week  quantity_of_sales  \
# 0                                 0.13731                 52
# 1                                 0.13731                 52
# 2                                 0.13731                 25
# 3                                 0.13731                518
# 4                                 0.13731                 24
#
#    sales_count_per_week  qnt_of_sales_per_sub_commodity_desc  \
# 0               8.66667                                  893
# 1               8.66667                                  893
# 2               4.16667                                 1105
# 3              86.33333                                 1811
# 4               4.00000                                 1105
#
#    qnt_of_sales_per_item_per_sub_commodity_desc_per_week marital_status_code  \
# 0                                                0.14620                   0
# 1                                                0.14620                   0
# 2                                                0.14221                   0
# 3                                                0.15639                   0
# 4                                                0.14221                   0
#
#   homeowner_desc hh_comp_desc household_size_desc     0_y     1_y     2_y  \
# 0              0            0                   0 0.00000 0.00000 0.00000
# 1              0            0                   0 0.00000 0.00000 0.00000
# 2              0            0                   0 0.00000 0.00000 0.00000
# 3              0            0                   0 0.00000 0.00000 0.00000
# 4              0            0                   0 0.00000 0.00000 0.00000
#
#       3_y     4_y     5_y     6_y     7_y     8_y     9_y    10_y    11_y  \
# 0 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000
# 1 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000
# 2 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000
# 3 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000
# 4 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000
#
#      12_y    13_y    14_y    15_y    16_y    17_y    18_y    19_y  mean_time  \
# 0 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000    0.00000
# 1 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000    0.00000
# 2 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000    0.00000
# 3 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000    0.00000
# 4 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000 0.00000    0.00000
#
#       age  income  children  avr_bask  sum_per_week  \
# 0 0.00000 0.00000   0.00000   0.00000       0.00000
# 1 0.00000 0.00000   0.00000   0.00000       0.00000
# 2 0.00000 0.00000   0.00000   0.00000       0.00000
# 3 0.00000 0.00000   0.00000   0.00000       0.00000
# 4 0.00000 0.00000   0.00000   0.00000       0.00000
#
#    count_purchases_week_mean  sum_purchases_week_mean  target
# 0                    0.00247                  0.01353 1.00000
# 1                    0.00247                  0.01353 1.00000
# 2                    0.00215                  0.00807 0.00000
# 3                    0.00192                  0.00310 0.00000
# 4                    0.00215                  0.00807 0.00000

# %%
TARGET_NAME = 'target'

corr_with_target = train.corr()[TARGET_NAME].sort_values(ascending=False)[1:]

plt.figure(figsize=(15, 20))

sns.barplot(x=corr_with_target.values, y=corr_with_target.index)

plt.title('Correlation with target variable')
plt.show()

# %%
df_num_features = train.select_dtypes(include = ['float64', 'int64'])
num_features = pd.DataFrame(df_num_features)

corr = num_features.corr()
plt.figure(figsize = (25, 17))
mask = np.zeros_like(corr, dtype=np.bool)  # отрезаем лишнюю половину матрицы
mask[np.triu_indices_from(mask)] = True
sns.set(font_scale=1.4)
sns.heatmap(num_features.corr(), mask=mask, annot=True, fmt='.1f', linewidths=.5, cmap='PuBu')
plt.title('Correlation matrix')
plt.show();

# %%
X_train = train.drop(['target'], axis=1)
y_train = train[['target']]

# %%
cat_features=[]
for col in X_train.columns:
    if(X_train[col].dtype == np.object):
          cat_features.append(col)
            
X_train[cat_features + ['user_id', 'item_id']] = X_train[cat_features + ['user_id', 'item_id']].astype('category')

# %%
cat_features
# Out:
# ['department',
#  'brand',
#  'commodity_desc',
#  'sub_commodity_desc',
#  'curr_size_of_product',
#  'marital_status_code',
#  'homeowner_desc',
#  'hh_comp_desc',
#  'household_size_desc']

# %%
test = extend_user_item_new_features(data_test, train_1, recommender, item_features, user_features, items_emb_df, users_emb_df, N)
X_test = test.drop(['target'], axis=1)
y_test = test[['target']]
X_test[cat_features + ['user_id', 'item_id']] = X_test[cat_features + ['user_id', 'item_id']].astype('category')

# %% [markdown]
# ### Second level model

# %%
lgbc = LGBMClassifier(objective='binary', max_depth=4, categorical_column=cat_features)

# %%
important_features = get_important_features(lgbc, X_train, y_train)
important_features
# Out:
# ['user_id',
#  'basket_id',
#  'day',
#  'item_id',
#  'quantity',
#  'sales_value',
#  'store_id',
#  'retail_disc',
#  'trans_time',
#  'price',
#  'brand',
#  'commodity_desc',
#  'sub_commodity_desc',
#  'curr_size_of_product',
#  '0_x',
#  '1_x',
#  '2_x',
#  '3_x',
#  '4_x',
#  '5_x',
#  '6_x',
#  '7_x',
#  '8_x',
#  '9_x',
#  '10_x',
#  '11_x',
#  '12_x',
#  '13_x',
#  '14_x',
#  '15_x',
#  '16_x',
#  '17_x',
#  '18_x',
#  '19_x',
#  'coupon_disc_y',
#  'sales_count_per_dep',
#  'qnt_of_sales_per_item_per_dep_per_week',
#  'quantity_of_sales',
#  'qnt_of_sales_per_sub_commodity_desc',
#  'qnt_of_sales_per_item_per_sub_commodity_desc_per_week',
#  '0_y',
#  '1_y',
#  '2_y',
#  '3_y',
#  '4_y',
#  '5_y',
#  '6_y',
#  '7_y',
#  '8_y',
#  '10_y',
#  '11_y',
#  '12_y',
#  '13_y',
#  '14_y',
#  '15_y',
#  '16_y',
#  '17_y',
#  '18_y',
#  '19_y',
#  'mean_time',
#  'age',
#  'income',
#  'avr_bask',
#  'sum_per_week',
#  'count_purchases_week_mean',
#  'sum_purchases_week_mean']

# %%
lgbc.fit(X_train[important_features], y_train)
# Out:
# LGBMClassifier(categorical_column=['department', 'brand', 'commodity_desc',
#                                    'sub_commodity_desc', 'curr_size_of_product',
#                                    'marital_status_code', 'homeowner_desc',
#                                    'hh_comp_desc', 'household_size_desc'],
#                max_depth=4, objective='binary')

# %%
# preds = lgbc.predict(X_test[important_features])
test_preds_proba = lgbc.predict_proba(X_test[important_features])[:, 1]

# %%
result = get_final_recomendations(X_test, test_preds_proba, data, train_1, item_features)
# Out:
# 100%|██████████| 2499/2499 [23:26<00:00,  1.78it/s]

# %% [markdown]
# ### Целевая метрика - precision@5 > 0.27%

# %%
final_result = result.apply(lambda row: precision_at_k(row['recomendations'], row['actual']), axis=1).mean()

# %%
final_result
# Out:
# 0.5049219687875142

# %% [markdown]
# ### Сохранение результатов

# %%
result.drop('actual', axis=1, inplace=True)

# %%
result.to_csv('recommendations.csv', index=False)
