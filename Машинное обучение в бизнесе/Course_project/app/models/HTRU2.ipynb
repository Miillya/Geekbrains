# %% [markdown]
# ## **HTRU2 Data Set**
#
# #### Описание данных - https://archive.ics.uci.edu/ml/datasets/HTRU2

# %% [markdown]
# ### Data Set Information:

# %% [markdown]
# HTRU2 is a data set which describes a sample of pulsar candidates collected during the High Time Resolution Universe Survey (South) [1].
#
# Pulsars are a rare type of Neutron star that produce radio emission detectable here on Earth. They are of considerable scientific interest as probes of space-time, the inter-stellar medium, and states of matter (see [2] for more uses).
#
# As pulsars rotate, their emission beam sweeps across the sky, and when this crosses our line of sight, produces a detectable pattern of broadband radio emission. As pulsars
# rotate rapidly, this pattern repeats periodically. Thus pulsar search involves looking for periodic radio signals with large radio telescopes.
#
# Each pulsar produces a slightly different emission pattern, which varies slightly with each rotation (see [2] for an introduction to pulsar astrophysics to find out why). Thus a potential signal detection known as a 'candidate', is averaged over many rotations of the pulsar, as determined by the length of an observation. In the absence of additional info, each candidate could potentially describe a real pulsar. However in practice almost all detections are caused by radio frequency interference (RFI) and noise, making legitimate signals hard to find.
#
# Machine learning tools are now being used to automatically label pulsar candidates to facilitate rapid analysis. Classification systems in particular are being widely adopted,
# (see [4,5,6,7,8,9]) which treat the candidate data sets as binary classification problems. Here the legitimate pulsar examples are a minority positive class, and spurious examples the majority negative class. At present multi-class labels are unavailable, given the costs associated with data annotation.
#
# The data set shared here contains 16,259 spurious examples caused by RFI/noise, and 1,639 real pulsar examples. These examples have all been checked by human annotators.
#
# The data is presented in two formats: CSV and ARFF (used by the WEKA data mining tool). Candidates are stored in both files in separate rows. Each row lists the variables first, and the class label is the final entry. The class labels used are 0 (negative) and 1 (positive).
#
# Please note that the data contains no positional information or other astronomical details. It is simply feature data extracted from candidate files using the PulsarFeatureLab tool (see [10]).

# %% [markdown]
# ### Attribute Information:

# %% [markdown]
# Each candidate is described by 8 continuous variables, and a single class variable. The first four are simple statistics obtained from the integrated pulse profile (folded profile). This is an array of continuous variables that describe a longitude-resolved version of the signal that has been averaged in both time and frequency (see [3] for more details). The remaining four variables are similarly obtained from the DM-SNR curve (again see [3] for more details). These are summarised below:
#
# 1. Mean of the integrated profile.
# 2. Standard deviation of the integrated profile.
# 3. Excess kurtosis of the integrated profile.
# 4. Skewness of the integrated profile.
# 5. Mean of the DM-SNR curve.
# 6. Standard deviation of the DM-SNR curve.
# 7. Excess kurtosis of the DM-SNR curve.
# 8. Skewness of the DM-SNR curve.
# 9. Class
#
# HTRU 2 Summary
# 17,898 total examples.
# 1,639 positive examples.
# 16,259 negative examples.

# %% [markdown]
# ### Подключение библиотек и скриптов

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:72,5% !important; }</style>"))
# Out:
# <style>.container { width:72,5% !important; }</style>

# %%
import pandas as pd
import numpy as np
import itertools

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams.update({'font.size': 14})
pd.set_option('precision', 3)
pd.set_option('max_columns', 100)
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('max_colwidth', 300)

# %% [markdown]
# ### Пути к директориям и файлам

# %%
TRAIN_DATASET_PATH = './HTRU2/HTRU_2.csv'

# %% [markdown]
# ### Загрузка данных

# %%
data = pd.read_csv(TRAIN_DATASET_PATH)

# %% [markdown]
# ### Изучение датасета

# %%
data.head()
# Out:
#    140.5625  55.68378214  -0.234571412  -0.699648398  3.199832776  \
# 0 102.50781     58.88243       0.46532      -0.51509      1.67726
# 1 103.01562     39.34165       0.32333       1.05116      3.12124
# 2 136.75000     57.17845      -0.06841      -0.63624      3.64298
# 3  88.72656     40.67223       0.60087       1.12349      1.17893
# 4  93.57031     46.69811       0.53190       0.41672      1.63629
#
#    19.11042633  7.975531794  74.24222492  0
# 0     14.86015     10.57649    127.39358  0
# 1     21.74467      7.73582     63.17191  0
# 2     20.95928      6.89650     53.59366  0
# 3     11.46872     14.26957    252.56731  0
# 4     14.54507     10.62175    131.39400  0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17897 entries, 0 to 17896
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   140.5625      17897 non-null  float64
#  1   55.68378214   17897 non-null  float64
#  2   -0.234571412  17897 non-null  float64
#  3   -0.699648398  17897 non-null  float64
#  4   3.199832776   17897 non-null  float64
#  5   19.11042633   17897 non-null  float64
#  6   7.975531794   17897 non-null  float64
#  7   74.24222492   17897 non-null  float64
#  8   0             17897 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %%
data.rename(columns={'140.5625': 'Mean of the integrated profile',
                     '55.68378214': 'Standard deviation of the integrated profile',
                     '-0.234571412': 'Excess kurtosis of the integrated profile',
                     '-0.699648398': 'Skewness of the integrated profile',
                     '3.199832776': 'Mean of the DM-SNR curve',
                     '19.11042633': 'Standard deviation of the DM-SNR curve',
                     '7.975531794': 'Excess kurtosis of the DM-SNR curv',
                     '74.24222492': 'Skewness of the DM-SNR curve',
                     '0': 'target'}, inplace=True)
# 1. Mean of the integrated profile - Среднее значение интегрированного профиля
# 2. Standard deviation of the integrated profile - Стандартное отклонение интегрированного профиля
# 3. Excess kurtosis of the integrated profile - Чрезмерный эксцесс интегрированного профиля
# 4. Skewness of the integrated profile - Асимметрия интегрированного профиля
# 5. Mean of the DM-SNR curve - Среднее значение кривой DM-SNR
# 6. Standard deviation of the DM-SNR curve - Стандартное отклонение кривой DM-SNR
# 7. Excess kurtosis of the DM-SNR curve - Избыточный эксцесс кривой DM-SNR
# 8. Skewness of the DM-SNR curve - Асимметрия кривой DM-SNR.
# 9. target - Целевая переменная.

# %%
data.tail()
# Out:
#        Mean of the integrated profile  \
# 17892                       136.42969
# 17893                       122.55469
# 17894                       119.33594
# 17895                       114.50781
# 17896                        57.06250
#
#        Standard deviation of the integrated profile  \
# 17892                                      59.84742
# 17893                                      49.48561
# 17894                                      59.93594
# 17895                                      53.90240
# 17896                                      85.79734
#
#        Excess kurtosis of the integrated profile  \
# 17892                                   -0.18785
# 17893                                    0.12798
# 17894                                    0.15936
# 17895                                    0.20116
# 17896                                    1.40639
#
#        Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 17892                            -0.73812                   1.29682
# 17893                             0.32306                  16.40970
# 17894                            -0.74303                  21.43060
# 17895                            -0.02479                   1.94649
# 17896                             0.08952                 188.30602
#
#        Standard deviation of the DM-SNR curve  \
# 17892                                12.16606
# 17893                                44.62689
# 17894                                58.87200
# 17895                                13.38173
# 17896                                64.71256
#
#        Excess kurtosis of the DM-SNR curv  Skewness of the DM-SNR curve  \
# 17892                            15.45026                     285.93102
# 17893                             2.94524                       8.29709
# 17894                             2.49952                       4.59517
# 17895                            10.00797                     134.23891
# 17896                            -1.59753                       1.42948
#
#        target
# 17892       0
# 17893       0
# 17894       0
# 17895       0
# 17896       0

# %% [markdown]
# data.info()

# %%
print(data.shape)
# Out:
# (17897, 9)

# %% [markdown]
# ### Количественные переменные

# %%
data.describe().T
# Out:
#                                                    count      mean       std  \
# Mean of the integrated profile               17897.00000 111.07832  25.65271
# Standard deviation of the integrated profile 17897.00000  46.54902   6.84304
# Excess kurtosis of the integrated profile    17897.00000   0.47790   1.06406
# Skewness of the integrated profile           17897.00000   1.77042   6.16806
# Mean of the DM-SNR curve                     17897.00000  12.61493  29.47364
# Standard deviation of the DM-SNR curve       17897.00000  26.32692  19.47104
# Excess kurtosis of the DM-SNR curv           17897.00000   8.30357   4.50622
# Skewness of the DM-SNR curve                 17897.00000 104.85942 106.51727
# target                                       17897.00000   0.09158   0.28844
#
#                                                   min       25%       50%  \
# Mean of the integrated profile                5.81250 100.92969 115.07812
# Standard deviation of the integrated profile 24.77204  42.37543  46.94644
# Excess kurtosis of the integrated profile    -1.87601   0.02711   0.22324
# Skewness of the integrated profile           -1.79189  -0.18853   0.19874
# Mean of the DM-SNR curve                      0.21321   1.92308   2.80184
# Standard deviation of the DM-SNR curve        7.37043  14.43733  18.45998
# Excess kurtosis of the DM-SNR curv           -3.13927   5.78149   8.43387
# Skewness of the DM-SNR curve                 -1.97698  34.95712  83.06900
# target                                        0.00000   0.00000   0.00000
#
#                                                    75%        max
# Mean of the integrated profile               127.08594  192.61719
# Standard deviation of the integrated profile  51.02289   98.77891
# Excess kurtosis of the integrated profile      0.47335    8.06952
# Skewness of the integrated profile             0.92821   68.10162
# Mean of the DM-SNR curve                       5.46488  223.39214
# Standard deviation of the DM-SNR curve        28.42815  110.64221
# Excess kurtosis of the DM-SNR curv            10.70297   34.53984
# Skewness of the DM-SNR curve                 139.31090 1191.00084
# target                                         0.00000    1.00000

# %% [markdown]
# ### Целевая переменная

# %%
data['target'].value_counts()
# Out:
# 0    16258
# 1     1639
# Name: target, dtype: int64

# %%
f, ax=plt.subplots(1, 2, figsize=(18, 8))
data['target'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Целевая переменная - target')
ax[0].set_ylabel('')
sns.countplot('target', data=data, ax=ax[1])
plt.show()

# %% [markdown]
# ###  Обработка выбросов и пропусков

# %%
data.isnull().sum()
# Out:
# Mean of the integrated profile                  0
# Standard deviation of the integrated profile    0
# Excess kurtosis of the integrated profile       0
# Skewness of the integrated profile              0
# Mean of the DM-SNR curve                        0
# Standard deviation of the DM-SNR curve          0
# Excess kurtosis of the DM-SNR curv              0
# Skewness of the DM-SNR curve                    0
# target                                          0
# dtype: int64

# %% [markdown]
# ### Корреляция признаков

# %%
TARGET_NAME = 'target'

corr_with_target = data.corr()[TARGET_NAME].sort_values(ascending=False)[1:]
plt.figure(figsize=(15, 20))
sns.barplot(x=corr_with_target.values, y=corr_with_target.index)
plt.title('Correlation with target variable')
plt.show()

# %%
# Correlation Matrix
f, ax = plt.subplots(figsize = [25, 17])
sns.heatmap(data.corr(), annot=True, fmt='.1f', linewidths=.5, ax=ax, cmap = 'PuBu' )
ax.set_title('Correlation Matrix', fontsize=25)
plt.show()

# %% [markdown]
# ### Feature engineering

# %%
plt.figure(figsize = (16, 8))
plt.scatter(data['Excess kurtosis of the integrated profile'], data['Excess kurtosis of the integrated profile'])
plt.ylabel('Excess kurtosis of the integrated profile')
plt.xlabel('Excess kurtosis of the integrated profile')
plt.title('Distribution of Excess kurtosis of the integrated profile by Excess kurtosis of the integrated profile')
plt.show();

# %%
data['Excess kurtosis of the integrated profile'].describe([.01,.1,.25,.5,.75,.9,.91,.92,.93,.94,.95,.96])
# Out:
# count   17897.00000
# mean        0.47790
# std         1.06406
# min        -1.87601
# 1%         -0.47919
# 10%        -0.13319
# 25%         0.02711
# 50%         0.22324
# 75%         0.47335
# 90%         0.89182
# 91%         1.01816
# 92%         1.21621
# 93%         1.61137
# 94%         2.13656
# 95%         2.70675
# 96%         3.34544
# max         8.06952
# Name: Excess kurtosis of the integrated profile, dtype: float64

# %% [markdown]
# ### PyCaret 2 Classification

# %%
from pycaret.classification import *
# https://pycaret.org/guide/
# https://github.com/pycaret/pycaret/blob/master/examples/PyCaret%202%20Classification.ipynb
# https://tproger.ru/translations/create-and-deploy-app-with-pycaret/

# %%
clf1 = setup(data = data, 
             target = 'target',
             silent = True)
# Out:
# <style  type="text/css" >
# </style><table id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row0_col1" class="data row0 col1" >6672</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row1_col1" class="data row1 col1" >target</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row4_col1" class="data row4 col1" >(17897, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row6_col1" class="data row6 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row11_col1" class="data row11 col1" >(12527, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row12_col1" class="data row12 col1" >(5370, 8)</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_19824ad8_2fb2_11eb_b84f_001a7dda7113row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %% [markdown]
# ### Compare Baseline

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113 th {
#           text-align: left;
#     }#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col0,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col3,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col6,#T_9e2e7b22_2fb2_11e ...
#             text-align:  left;
#             text-align:  left;
#         }#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col1,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col2,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col5,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col6,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col7,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col4,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row11_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row0_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row1_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row2_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row3_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row4_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row5_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row6_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row7_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row8_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row9_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row11_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row12_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row13_col8,#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113row10_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e2e7b22_2fb2_11eb_bc22_001a7dda7113level0_row0" class="row_heading level0 row0" >catboost</t

# %% [markdown]
# ### Create Model

# %%
model_cbc = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_70e66640_2fb3_11eb_87ef_001a7dda7113row10_col0,#T_70e66640_2fb3_11eb_87ef_001a7dda7113row10_col1,#T_70e66640_2fb3_11eb_87ef_001a7dda7113row10_col2,#T_70e66640_2fb3_11eb_87ef_001a7dda7113row10_col3,#T_70e66640_2fb3_11eb_87ef_001a7dda7113row10_col4,#T_70e66640_2fb3_11eb_87ef_001a7dda7113row10_col5,#T_70e66640_2fb3_11eb_87ef_001a7dda7113row10_col6{
#             background:  yellow;
#         }</style><table id="T_70e66640_2fb3_11eb_87ef_001a7dda7113" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row0_col0" class="data row0 col0" >0.9808</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row0_col1" class="data row0 col1" >0.9765</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row0_col2" class="data row0 col2" >0.8522</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row0_col3" class="data row0 col3" >0.9333</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row0_col4" class="data row0 col4" >0.8909</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row0_col5" class="data row0 col5" >0.8804</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row0_col6" class="data row0 col6" >0.8815</td>
#             </tr>
#             <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row1_col0" class="data row1 col0" >0.9856</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row1_col1" class="data row1 col1" >0.9868</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row1_col2" class="data row1 col2" >0.8696</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row1_col3" class="data row1 col3" >0.9709</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row1_col4" class="data row1 col4" >0.9174</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row1_col5" class="data row1 col5" >0.9096</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row1_col6" class="data row1 col6" >0.9112</td>
#             </tr>
#             <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row2_col0" class="data row2 col0" >0.9808</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row2_col1" class="data row2 col1" >0.9837</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row2_col2" class="data row2 col2" >0.8522</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row2_col3" class="data row2 col3" >0.9333</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row2_col4" class="data row2 col4" >0.8909</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row2_col5" class="data row2 col5" >0.8804</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row2_col6" class="data row2 col6" >0.8815</td>
#             </tr>
#             <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row3_col0" class="data row3 col0" >0.9785</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row3_col1" class="data row3 col1" >0.9680</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row3_col2" class="data row3 col2" >0.8261</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row3_col3" class="data row3 col3" >0.9314</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row3_col4" class="data row3 col4" >0.8756</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row3_col5" class="data row3 col5" >0.8638</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row3_col6" class="data row3 col6" >0.8657</td>
#             </tr>
#             <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row4_col0" class="data row4 col0" >0.9777</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row4_col1" class="data row4 col1" >0.9712</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row4_col2" class="data row4 col2" >0.8348</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row4_col3" class="data row4 col3" >0.9143</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row4_col4" class="data row4 col4" >0.8727</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row4_col5" class="data row4 col5" >0.8605</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row4_col6" class="data row4 col6" >0.8616</td>
#             </tr>
#             <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row5_col0" class="data row5 col0" >0.9816</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row5_col1" class="data row5 col1" >0.9733</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row5_col2" class="data row5 col2" >0.8448</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row5_col3" class="data row5 col3" >0.9515</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row5_col4" class="data row5 col4" >0.8950</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row5_col5" class="data row5 col5" >0.8850</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row5_col6" class="data row5 col6" >0.8868</td>
#             </tr>
#             <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row6_col0" class="data row6 col0" >0.9792</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row6_col1" class="data row6 col1" >0.9751</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row6_col2" class="data row6 col2" >0.8966</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row6_col3" class="data row6 col3" >0.8814</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row6_col4" class="data row6 col4" >0.8889</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row6_col5" class="data row6 col5" >0.8774</td>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row6_col6" class="data row6 col6" >0.8775</td>
#             </tr>
#             <tr>
#                         <th id="T_70e66640_2fb3_11eb_87ef_001a7dda7113level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_70e66640_2fb3_11eb_87ef_001a7dda7113row7_co

# %% [markdown]
# ### Tune Hyperparameters

# %%
tuned_cbc = tune_model(model_cbc)
# Out:
# <style  type="text/css" >
# #T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row10_col0,#T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row10_col1,#T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row10_col2,#T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row10_col3,#T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row10_col4,#T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row10_col5,#T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row10_col6{
#             background:  yellow;
#         }</style><table id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row0_col0" class="data row0 col0" >0.9800</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row0_col1" class="data row0 col1" >0.9745</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row0_col2" class="data row0 col2" >0.8435</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row0_col3" class="data row0 col3" >0.9327</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row0_col4" class="data row0 col4" >0.8858</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row0_col5" class="data row0 col5" >0.8749</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row0_col6" class="data row0 col6" >0.8763</td>
#             </tr>
#             <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row1_col0" class="data row1 col0" >0.9864</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row1_col1" class="data row1 col1" >0.9858</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row1_col2" class="data row1 col2" >0.8783</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row1_col3" class="data row1 col3" >0.9712</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row1_col4" class="data row1 col4" >0.9224</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row1_col5" class="data row1 col5" >0.9150</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row1_col6" class="data row1 col6" >0.9163</td>
#             </tr>
#             <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row2_col0" class="data row2 col0" >0.9832</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row2_col1" class="data row2 col1" >0.9834</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row2_col2" class="data row2 col2" >0.8522</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row2_col3" class="data row2 col3" >0.9608</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row2_col4" class="data row2 col4" >0.9032</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row2_col5" class="data row2 col5" >0.8941</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row2_col6" class="data row2 col6" >0.8960</td>
#             </tr>
#             <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row3_col0" class="data row3 col0" >0.9785</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row3_col1" class="data row3 col1" >0.9730</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row3_col2" class="data row3 col2" >0.8174</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row3_col3" class="data row3 col3" >0.9400</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row3_col4" class="data row3 col4" >0.8744</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row3_col5" class="data row3 col5" >0.8627</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row3_col6" class="data row3 col6" >0.8652</td>
#             </tr>
#             <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row4_col0" class="data row4 col0" >0.9792</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row4_col1" class="data row4 col1" >0.9715</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row4_col2" class="data row4 col2" >0.8348</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row4_col3" class="data row4 col3" >0.9320</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row4_col4" class="data row4 col4" >0.8807</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row4_col5" class="data row4 col5" >0.8694</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row4_col6" class="data row4 col6" >0.8710</td>
#             </tr>
#             <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row5_col0" class="data row5 col0" >0.9808</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row5_col1" class="data row5 col1" >0.9731</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row5_col2" class="data row5 col2" >0.8362</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row5_col3" class="data row5 col3" >0.9510</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row5_col4" class="data row5 col4" >0.8899</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row5_col5" class="data row5 col5" >0.8795</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row5_col6" class="data row5 col6" >0.8816</td>
#             </tr>
#             <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row6_col0" class="data row6 col0" >0.9800</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row6_col1" class="data row6 col1" >0.9773</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row6_col2" class="data row6 col2" >0.8879</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row6_col3" class="data row6 col3" >0.8957</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row6_col4" class="data row6 col4" >0.8918</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row6_col5" class="data row6 col5" >0.8808</td>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row6_col6" class="data row6 col6" >0.8808</td>
#             </tr>
#             <tr>
#                         <th id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3f875b1e_2fb4_11eb_aca7_001a7dda7113row7_co

# %% [markdown]
# ### Analyze Model

# %%
# Learning Curve
plot_model(estimator = tuned_cbc, plot = 'learning')

# %%
# AUC Curve
plot_model(estimator = tuned_cbc, plot = 'auc')

# %%
# Confusion Matrix
plot_model(estimator = tuned_cbc, plot = 'confusion_matrix')

# %%
# Feature Importance
plot_model(estimator = tuned_cbc, plot = 'feature')

# %%
plot_model(tuned_cbc, plot = 'boundary')

# %%
plot_model(tuned_cbc, plot = 'pr')

# %%
plot_model(tuned_cbc, plot = 'class_report')

# %%
evaluate_model(tuned_cbc)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Interpret Model

# %%
interpret_model(tuned_cbc)

# %%
interpret_model(tuned_cbc, plot = 'correlation')

# %% [markdown]
# ### Predict Model

# %%
predictions = predict_model(tuned_cbc)
predictions.head()
# Out:
# <style  type="text/css" >
# </style><table id="T_e904751e_2fb5_11eb_a331_001a7dda7113" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e904751e_2fb5_11eb_a331_001a7dda7113level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col1" class="data row0 col1" >0.9801</td>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col2" class="data row0 col2" >0.9805</td>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col3" class="data row0 col3" >0.8542</td>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col4" class="data row0 col4" >0.9204</td>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col5" class="data row0 col5" >0.8860</td>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col6" class="data row0 col6" >0.8751</td>
#                         <td id="T_e904751e_2fb5_11eb_a331_001a7dda7113row0_col7" class="data row0 col7" >0.8759</td>
#             </tr>
#     </tbody></table>
#    Mean of the integrated profile  \
# 0                       124.27344
# 1                       130.76562
# 2                       113.27344
# 3                       138.71094
# 4                        99.67969
#
#    Standard deviation of the integrated profile  \
# 0                                      53.45306
# 1                                      53.61108
# 2                                      51.72263
# 3                                      44.95417
# 4                                      51.39308
#
#    Excess kurtosis of the integrated profile  \
# 0                                    0.04793
# 1                                    0.10536
# 2                                    0.22347
# 3                                   -0.05543
# 4                                    0.51087
#
#    Skewness of the integrated profile  Mean of the DM-SNR curve  \
# 0                            -0.52468                   3.22575
# 1                            -0.05996                   7.86873
# 2                            -0.32327                   9.01672
# 3                             0.39495                   1.07274
# 4                            -0.40203                   5.70318
#
#    Standard deviation of the DM-SNR curve  Excess kurtosis of the DM-SNR curv  \
# 0                                15.25576                             7.41510
# 1                                34.96071                             4.81593
# 2                                43.23164                             4.60164
# 3                                11.37101                            14.26188
# 4                                23.60998                             5.28557
#
#    Skewness of the DM-SNR curve target  Label   Score
# 0                      80.41068      0      0 0.99840
# 1                      23.32428      0      0 0.99650
# 2                      19.25739      0      0 0.99080
# 3                     252.17697      0      0 0.99860
# 4                      32.43966      0      0 0.96410

# %% [markdown]
# ### Save / Load Model

# %%
save_model(tuned_cbc, model_name='model_cbc')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='target',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='target')),
#                  ('fix_perfect', Remove_100(target='target')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   <catboost.core.CatBoostClassifier object at 0x0000028DF948DB88>]],
#           verbose=False), 'model_cbc.pkl')
